# %% [markdown]
# # PROJECT : REAL-TIME AQI ANALYSIS AND VISUALIZATION OF INDIA

# %% [markdown]
# # - IMPORTING NECESSARY LIBRARIES :

# %%
import pandas as pd
import folium
from folium.plugins import HeatMap

# %% [markdown]
# # ###-STEP 1 DOWNLOAD DATA

# %%
# Details of API at:- https://aqicn.org/api/
base_url = "https://api.waqi.info"

# %% [markdown]
# # Got a special User token from:- https://aqicn.org/data-platform/token/#/ by registering myself on this site.

# %%
tok = "0976e0617860ee99e9fbbfb1e3f84c9e44fd4fa2"

# %% [markdown]
# # (lat, long)-> bottom left, (lat, lon)-> top right

# %% [markdown]
# # Location of India is 8N 61E to 37N, 97E approx

# %%
latlngbox = "8.0000,61.0000,37.0000,97.0000" # For India

# %%
trail_url=f"/map/bounds/?latlng={latlngbox}&token={tok}"

# %% [markdown]
# # Joining the parts of URL:

# %%
my_data = pd.read_json(base_url + trail_url)

# %% [markdown]
# # Printing 2 cols ‘status’ and ‘data’

# %%
print('columns->', my_data.columns)
# Out:
# columns-> Index(['status', 'data'], dtype='object')

# %% [markdown]
# # ###-STEP 2:- Create table like DataFrame

# %%
all_rows = []
for each_row in my_data['data']:
    all_rows.append([each_row['station']['name'],each_row['lat'],each_row['lon'],each_row['aqi']])
    df = pd.DataFrame(all_rows,
    columns=['station_name', 'lat', 'lon', 'aqi'])

# %% [markdown]
# # ### -STEP 3:- Cleaning the DataFrame#

# %% [markdown]
# # Converting Invalid parse to NaN

# %%
df['aqi'] = pd.to_numeric(df.aqi,
errors='coerce')

# %% [markdown]
# # Printing Values with NaN :

# %%
print('with NaN->', df.shape)
# Out:
# with NaN-> (207, 4)

# %% [markdown]
# #  Remove NaN (Not a Number) entries in column:

# %%
df1 = df.dropna(subset = ['aqi'])

# %% [markdown]
# # Printing Values Without NaN:

# %%
print('without NaN->', df1.shape)
# Out:
# without NaN-> (199, 4)

# %% [markdown]
# # ###-STEP 4:- Making folium heat map

# %%
df2 = df1[['lat', 'lon', 'aqi']]

# %% [markdown]
# # To Print Our DataFrame:

# %%
print(df2.head)
# Out:
# <bound method NDFrame.head of            lat        lon    aqi
# 0    29.800600  76.415500  357.0
# 1    19.110740  72.860840  179.0
# 2    22.969611  72.643500  160.0
# 3    28.376058  77.315741  289.0
# 4    28.422700  77.066700  211.0
# ..         ...        ...    ...
# 202  30.719859  76.738637  201.0
# 203  27.573483  84.498578  148.0
# 204  27.422675  85.034416   55.0
# 205  24.261301  80.723178   98.0
# 206  23.233584  77.400574  155.0
#
# [199 rows x 3 columns]>

# %% [markdown]
# # Giving Central Location:

# %%
init_loc = [23, 77] # Approx over Bhopal

# %% [markdown]
# # Getting and Printing Max_Aqi of Locations:

# %%
max_aqi = int(df1['aqi'].max())
print('max_aqi->', max_aqi)
# Out:
# max_aqi-> 562

# %% [markdown]
# # Visualization Of Live_HeatMap of India:

# %%
m = folium.Map(location = init_loc, zoom_start = 5)
 
heat_aqi = HeatMap(df2, min_opacity = 0.1, max_val = max_aqi,
radius = 20, blur = 20, max_zoom = 2)
m.add_child(heat_aqi)
m # Show the map
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10404\2687615664.py:3: UserWarning: The `max_val` parameter is no longer necessary. The largest intensity is calculated automatically.
#   heat_aqi = HeatMap(df2, min_opacity = 0.1, max_val = max_aqi,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8254d357fe81309f5ec9ecf9e58bdb5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_
 76.9938, 64.0], [24.8415, 67.0091, 169.0], [10.942451, 76.978996, 134.0], [20.0073285, 73.7762427, 157.0], [22.627847, 88.380669, 166.0], [25.366336, 87.117468, 303.0], [25.376776, 86.471523, 95.0], [26.1209, 85.3647, 221.0], [28.9535882, 77.7622941, 185.0], [28.52123, 76.37138, 191.0], [29.6475, 91.0874, 43.0], [22.58157048, 88.41002457, 128.0], [22.629801, 88.352017, 152.0], [25.0328, 85.41948, 172.0], [29.6953, 77.0027, 247.0], [28.060249, 76.113115, 151.0], [29.4723508, 77.7194031, 181.0], [28.964949, 77.278761, 217.0], [31.560078, 74.33589, 180.0], [23.796373, 90.424614, 107.0], [13.1036, 80.2909, 110.0], [17.72, 83.3, 162.0], [28.704133, 80.5945, 85.0], [33.7235, 73.11822, 163.0], [28.840739, 78.697531, 153.0], [28.725645, 77.749675, 242.0], [28.194909, 76.862296, 197.0], [30.649961, 76.331442, 316.0], [31.4846, 92.0657, 119.0], [25.555605, 83.950942, 1.0], [31.62, 74.876512, 156.0], [34.066206, 74.81982, 75.0], [28.820629, 77.101099, 354.0], [16.802639, 75.722694, 68.0], [25.444266, 86.140169, 237.0], [23.50016, 80.23284, 191.0], [26.470859, 74.646594, 111.0], [27.712463, 85.315704, 157.0], [28.406963, 77.849831, 173.0], [28.88528, 78.7388, 85.0], [29.497973, 76.993331, 396.0], [8.8787, 76.6073, 103.0], [12.9099161, 80.1076538, 65.0], [11.875, 75.3732, 122.0], [17.4559458, 78.4332152, 157.0], [25.892357, 86.590325, 293.0], [26.1403345, 85.3650192, 238.0], [28.38910936, 79.42963708, 127.0], [25.771061, 73.340227, 156.0], [8.816428, 78.0 ...

# %% [markdown]
# # ###-STEP 5 : Ploting stations on map

# %%
centre_point = [23.25, 77.41] # Approx over Bhopal
m2 = folium.Map(location = centre_point,
tiles = 'Stamen Terrain',
zoom_start= 6)
for idx, row in df1.iterrows():
    lat = row['lat']
    lon = row['lon']
    station = row['station_name'] + ' AQI=' + str(row['aqi'])
    station_aqi = row['aqi']
    if station_aqi > 300: ## Red for very bad AQI
        pop_color = 'red'
    elif station_aqi > 200:
        pop_color = 'orange' ## Orange for moderate AQI
    else:
        pop_color = 'green' ## Green for good AQI
    folium.Marker(location= [lat, lon],
    popup = station,
    icon = folium.Icon(color = pop_color)).add_to(m2)
m2 # Display map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5274bad2224ae91433cbab4348257063 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5274bad2224ae91433cbab4348257063&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5274bad2224ae91433cbab4348257063 = L.map(
#                 &quot;map_5274bad2224ae91433cbab4348257063&quot;,
#                 {
#                     center: [23.25, 77.41],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_219dcdf424efec772bd8c7b3071232f4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5274bad2224ae91433cbab4348257063);
#
#
#             var marker_e42d4e1d70b576cce3f288c3b22e482b = L.marker(
#                 [29.8006, 76.4155],
#                 {}
#             ).addTo(map_5274bad2224ae91433cbab4348257063);
#
#
#             var icon_a01bf1cc92e6d3d6fd4a2bfb66eb5a3b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e42d4e1d70b576cce3f288c3b22e482b.setIcon(icon_a01bf1cc92e6d3d6fd4a2bfb66eb5a3b);
#
#
#         var popup_a8eb715cdab91641466d92027b7b09d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_182bc4491ad4f3d5f156e9a5bccd336b = $(`&lt;div id=&quot;html_182bc4491ad4f3d5f156e9a5bccd336b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rishi Nagar, Kaithal, India AQI=357.0&lt;/div&gt;`)[0];
#                 popup_a8eb715cdab91641466d92027b7b09d4.setContent(html_182bc4491ad4f3d5f156e9a5bccd336b);
#
#
#
#         marker_e42d4e1d70b576cce3f288c3b22e482b.bindPopup(popup_a8eb715cdab91641466d92027b7b09d4)
#         ;
#
#
#
#
#             var marker_7031cde2ea6a802753640fe8922ed9ac = L.marker(
#                 [19.11074, 72.86084],
#                 {}
#             ).addTo(map_5274bad2224ae91433cbab4348257063);
#
#
#             var icon_85175cb5e251b9d61a67385fe48de6b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7031cde2ea6a802753640fe8922ed9ac.setIcon(icon_85175cb5e251b9d61a67385fe48de6b1);
#
#
#         var popup_e7aa439d41156828a99d96c18c71f41b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a6f89a0aa945588a9ef04f363aea28f1 = $(`&lt;div id=&quot;html_a6f89a0aa945588a9ef04f363aea28f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chakala-Andheri East, Mumbai, India AQI=179.0&lt;/div&gt;`)[0];
#                 popup_e7aa439d41156828a99d96c18c71f41b.setContent(html_a6f89a0aa945588a9ef04f363aea28f1);
#
#
#
#         marker_7031cde2ea6a802753640fe8922ed9ac.bindPopup(popup_e7aa439d41156828a99d96c18c71f41b)
#         ;
#
#
#
#
#             var marker_81a9a8194908bf5b979e4528747405c1 = L.marker(
#                 [22.969611, 72.6435],
#                 {}
#             ).addTo(map_5274bad2224ae91433cbab4348257063);
#
#
#             var icon_8d19ccef0ea35bdce9af2d0e07b24b15 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_81a9a8194908bf5b979e4528747405c1.setIcon(icon_8d19ccef0ea35bdce9af2d0e07b24b15);
#
#
#         var popup_a2621392badac4aa8d6517649e51aec9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32827698b8f93e1365a0e5ae30f52966 = $(`&lt;div id=&quot;html_32827698b8f93e1365a0e5ae30f52966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Phase-4 GIDC, Vatva, India AQI=160.0&lt;/div&gt;`)[0];
#                 popup_a2621392badac4aa8d6517649e51aec9.setContent(html_32827698b8f93e1365a0e5ae30f52966);
#
#
#
#         marker_81a9a8194908bf5b979e4528747405c1.bindPopup(popup_a2621392badac4aa8d6517649e51aec9)
#         ;
#
#
#
#
#             var marker_c6f2750c74b697146df2a0b82b5dc7b4 = L.marker(
#                 [28.376058, 77.315741],
#                 {}
#             ).addTo(map_5274bad2224ae91433cbab4348257063);
#
#
#             var icon_f1a

# %%
import requests
import json
import pandas as pd
import re
import datetime
import time
import base64
from itertools import product

stationsData = pd.read_csv("C:/Users/hp/OneDrive/Desktop/PROJECT 3rd Sem/station.csv")

def getData(api, filters):
    url1 = "https://api.data.gov.in/resource/3b01bcb8-0b14-4abf-b6f2-c1bfd384ba69?api-key=" + api + "&format=json&limit=500"
    criteriaAll = [[(k, re.sub(r'\s+', '%20', v)) for v in criteria[k]] for k in criteria]
    url2 = [url1 + ''.join(f'&filters[{ls}]={value}' for ls, value in p) for p in product(*criteriaAll)]
    
    pollutionDfAll = pd.DataFrame()
    for i in url2:
        response = requests.get(i, verify=True)
        response_dict = json.loads(response.text)
        pollutionDf = pd.DataFrame(response_dict['records'])
        pollutionDfAll = pd.concat([pollutionDfAll, pollutionDf])
    
    return pollutionDfAll



api ="579b464db66ec23bdd000001fcbeb272b328454e41d1cd46d77298ba"

# %% [markdown]
# # In the code below, there are two arguments that we needs to input - API Key Filter criteria. Filter criteria can have "state", "city", "station", "pollutant_id". To see the unique values of state, city and station, you can download and refer the dataset shown above. Distinct values of pollutant_id are as follows -"PM2.5" "PM10"  "NO2"   "NH3"   "SO2"   "CO"    "OZONE"

# %%
criteria = {'city':["Rupnagar","Punjab"], 'pollutant_id': ["PM10", "PM2.5","NO2","NH3","SO2","CO","OZONE"]}
mydata = getData(api, criteria)
mydata
# Out:
#      id country   state      city                               station  \
# 0  1406   India  Punjab  Rupnagar  Ratanpura, Rupnagar - Ambuja Cements
# 0  1405   India  Punjab  Rupnagar  Ratanpura, Rupnagar - Ambuja Cements
# 0  1407   India  Punjab  Rupnagar  Ratanpura, Rupnagar - Ambuja Cements
# 0  1408   India  Punjab  Rupnagar  Ratanpura, Rupnagar - Ambuja Cements
# 0  1409   India  Punjab  Rupnagar  Ratanpura, Rupnagar - Ambuja Cements
#
#            last_update pollutant_id pollutant_min pollutant_max pollutant_avg  \
# 0  10-11-2022 09:00:00         PM10            99           162           131
# 0  10-11-2022 09:00:00        PM2.5            58           308           156
# 0  10-11-2022 09:00:00          NO2            11            29            18
# 0  10-11-2022 09:00:00          SO2             5             9             7
# 0  10-11-2022 09:00:00           CO            26            84            44
#
#   pollutant_unit
# 0             NA
# 0             NA
# 0             NA
# 0             NA
# 0             NA

# %% [markdown]
# # To find AQI score of station(s) which is the most granular level of information. We can club it with the pollutant ID to narrow down Our search result.

# %%
criteria = {"station":["Anand Vihar, Delhi - DPCC", "Okhla Phase-2, Delhi - DPCC"], "pollutant_id":["PM10"]}
mydata = getData(api, criteria)
mydata
# Out:
#     id country  state   city                      station  \
# 0  303   India  Delhi  Delhi    Anand Vihar, Delhi - DPCC
# 0  449   India  Delhi  Delhi  Okhla Phase-2, Delhi - DPCC
#
#            last_update pollutant_id pollutant_min pollutant_max pollutant_avg  \
# 0  10-11-2022 09:00:00         PM10           131           500           329
# 0  10-11-2022 09:00:00         PM10           133           441           274
#
#   pollutant_unit
# 0             NA
# 0             NA

# %%
criteria={"station": ["Sector 22, Chandigarh - CPCC"],'pollutant_id': ["PM10", "PM2.5","NO2","NH3","SO2","CO","OZONE"]}
mydata = getData(api, criteria)
mydata
# Out:
#     id country       state        city                       station  \
# 0  270   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
# 0  269   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
# 0  271   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
# 0  272   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
# 0  273   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
# 0  274   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
# 0  275   India  Chandigarh  Chandigarh  Sector 22, Chandigarh - CPCC
#
#            last_update pollutant_id pollutant_min pollutant_max pollutant_avg  \
# 0  10-11-2022 09:00:00         PM10           121           392           217
# 0  10-11-2022 09:00:00        PM2.5           187           401           323
# 0  10-11-2022 09:00:00          NO2            33           190            79
# 0  10-11-2022 09:00:00          NH3             1            11             7
# 0  10-11-2022 09:00:00          SO2             9            70            22
# 0  10-11-2022 09:00:00           CO            20           129            31
# 0  10-11-2022 09:00:00        OZONE            11           268            39
#
#   pollutant_unit
# 0             NA
# 0             NA
# 0             NA
# 0             NA
# 0             NA
# 0             NA
# 0             NA
